# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
jumping_jen = pd.read_csv('../datasets/cleaned_data/jen_jumping_cleaned.csv')
jumping_shreya = pd.read_csv('../datasets/cleaned_data/shreya_jumping_cleaned.csv')
jumping_sirui = pd.read_csv('../datasets/cleaned_data/sirui_jumping_cleaned.csv')

jumping_jen["User"] = 1
jumping_shreya["User"] = 2
jumping_sirui["User"] = 3

jumping_all = jumping_jen.append(jumping_shreya, ignore_index=True).append(jumping_sirui, ignore_index=True)

jumping_all.shape

jumping_all["Activity"] = 2

# %%
running_jen = pd.read_csv('../datasets/cleaned_data/jen_running_cleaned.csv')
running_shreya = pd.read_csv('../datasets/cleaned_data/shreya_running_cleaned.csv')
running_sirui = pd.read_csv('../datasets/cleaned_data/sirui_running_cleaned.csv')

running_jen["User"] = 1
running_shreya["User"] = 2
running_sirui["User"] = 3

running_all = running_jen.append(running_shreya, ignore_index=True).append(running_sirui, ignore_index=True)

running_all.shape

running_all["Activity"] = 3

# %%
walking_jen = pd.read_csv('../datasets/cleaned_data/jen_walking_cleaned.csv')
walking_shreya = pd.read_csv('shreya_walking_cleaned.csv')
walking_sirui = pd.read_csv('sirui_walking_cleaned.csv')

walking_jen["User"] = 1
walking_shreya["User"] = 2
walking_sirui["User"] = 3

walking_all = walking_jen.append(walking_shreya, ignore_index=True).append(walking_sirui, ignore_index=True)

walking_all.shape

walking_all["Activity"] = 1

# %% [markdown]
# ### Mark actitvities:
# Stand: 0
# Walking: 1
# Jumping: 2
# Running: 3

# %%
act_dict = {0: 'stand',
            1: 'walk',
            2: 'jump',
            3: 'run'}

# %%
data_all = walking_all.append(running_all, ignore_index=True).append(jumping_all, ignore_index=True)

# %%
data_all.shape
# Out:
# (4215, 15)

# %%
data_all['label'] =  data_all.Activity.apply(lambda Activity: act_dict[Activity])

# %%
data_all.head()
# Out:
#         G1X       G1Y       G1Z       A1X       A1Y       A1Z       G2X  \
# 0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.091553
# 1  0.823975  1.937866  1.350403  0.008545  0.027344  0.006836  0.282288
# 2  0.701904  1.693726  0.976562  0.011475  0.035645  0.013672  0.473022
# 3  1.564026  1.762390  0.480652  0.009521  0.050049  0.013916  1.319885
# 4  1.205444  1.449585  0.358582  0.007080  0.015625  0.017334  0.862122
#
#         G2Y       G2Z       A2X       A2Y       A2Z     timestamp  User  \
# 0  1.815796  0.358582  0.012451  0.026611  0.003906  1.635344e+12     1
# 1  1.258850  1.518250  0.011963  0.014160  0.003418  1.635344e+12     1
# 2  1.327515  0.923157  0.015625  0.039795  0.006104  1.635344e+12     1
# 3  0.038147  1.304626  0.051270  0.004395  0.047852  1.635344e+12     1
# 4  0.473022  0.000000  0.031250  0.031738  0.042236  1.635344e+12     1
#
#    Activity label
# 0         1  walk
# 1         1  walk
# 2         1  walk
# 3         1  walk
# 4         1  walk

# %% [markdown]
# ## Data Exploratory Analysis

# %%
metrics = ['G1X', 'G1Y', 'G1Z', 'A1X', 'A1Y', 'A1Z', 'G2X', 'G2Y', 'G2Z', 'A2X', 'A2Y', 'A2Z']

# %%
def plot_data(start_position, number_of_frames, metrics=metrics, fourier=False):
    print(f"Looking at {metrics} for {number_of_frames} from {start_position}")
   
    i, j = 0, 0
    for label in data_all.label.unique():
        mini_df = data_all[data_all['label']==label].iloc[start_position:start_position+number_of_frames].reset_index()
        for metric in metrics:
            if metric in ['G2X', 'G2Y', 'G2Z', 'A2X', 'A2Y', 'A2Z']:
                axs[i, 1].plot(mini_df[metric])
            else:
                axs[i, 0].plot(mini_df[metric])
                i = i + 1

# %%
plt.rcParams["figure.figsize"] = (20,7)
jumping_all['A1X'].iloc[3:50].plot()
jumping_all['A1Y'].iloc[3:50].plot()
jumping_all['A1Z'].iloc[3:50].plot()
plt.legend()

# %%
def plot_activity(activity, data):

    fig, (ax0, ax1, ax2) = plt.subplots(nrows=3,
         figsize=(15, 10),
         sharex=True)
    plot_axis(ax0, range(len(data['timestamp'])), data['A1X'], 'A1X-Axis')
    plot_axis(ax1, range(len(data['timestamp'])), data['A1Y'], 'A1Y-Axis')
    plot_axis(ax2, range(len(data['timestamp'])), data['A1Z'], 'A1Z-Axis')
    plt.subplots_adjust(hspace=0.2)
    fig.suptitle(activity)
    plt.subplots_adjust(top=0.90)
    plt.show()

def plot_axis(ax, x, y, title):

    ax.plot(x, y, 'r')
    ax.set_title(title)
    ax.xaxis.set_visible(False)
    ax.set_ylim([min(y) - np.std(y), max(y) + np.std(y)])
    ax.set_xlim([min(x), max(x)])
    ax.grid(True)

for label in np.unique(data_all['label']):
    subset = data_all[data_all['label'] == label][:180]
    plot_activity(label, subset)

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import coremltools
from scipy import stats
from IPython.display import display, HTML

from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn import preprocessing

import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Reshape
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import np_utils
# Out:
# WARNING:root:scikit-learn version 1.0.1 is not supported. Minimum required version: 0.17. Maximum required version: 0.19.2. Disabling scikit-learn conversion API.
# WARNING:root:TensorFlow version 2.6.1 detected. Last version known to be fully compatible is 2.3.1 .
# WARNING:root:Keras version 2.6.0 detected. Last version known to be fully compatible of Keras is 2.2.4 .

# %%
# Define column name of the label vector
LABEL = 'ActivityEncoded'
# Transform the labels from String to Integer via LabelEncoder
le = preprocessing.LabelEncoder()
# Add a new column to the existing DataFrame with the encoded values
data_all[LABEL] = le.fit_transform(data_all['Activity'].values.ravel())

# %%
data_all.columns
# Out:
# Index(['G1X', 'G1Y', 'G1Z', 'A1X', 'A1Y', 'A1Z', 'G2X', 'G2Y', 'G2Z', 'A2X',
#        'A2Y', 'A2Z', 'timestamp', 'User', 'Activity', 'label',
#        'ActivityEncoded'],
#       dtype='object')

# %%
df_test = data_all[data_all['User'] > 2]
df_train = data_all[data_all['User'] <= 2]

# %%
metrics = ['G1X', 'G1Y', 'G1Z', 'A1X', 'A1Y', 'A1Z', 'G2X', 'G2Y', 'G2Z', 'A2X', 'A2Y', 'A2Z']

# %%
pd.options.mode.chained_assignment = None  # default='warn'
for metric in metrics:
    df_train[metric] = df_train[metric] / df_train[metric].max()
# Round numbers
round_dict = {metric: 4 for metric in metrics}
df_train = df_train.round(round_dict)

# %%
df_train.head()
# Out:
#       G1X     G1Y     G1Z     A1X     A1Y     A1Z     G2X     G2Y     G2Z  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0471  0.9333  0.1843
# 1  0.4235  0.9961  0.6941  0.1373  0.4392  0.1098  0.1451  0.6471  0.7804
# 2  0.3608  0.8706  0.5020  0.1843  0.5725  0.2196  0.2431  0.6824  0.4745
# 3  0.8039  0.9059  0.2471  0.1529  0.8039  0.2235  0.6784  0.0196  0.6706
# 4  0.6196  0.7451  0.1843  0.1137  0.2510  0.2784  0.4431  0.2431  0.0000
#
#       A2X     A2Y     A2Z     timestamp  User  Activity label  ActivityEncoded
# 0  0.2000  0.4275  0.0627  1.635344e+12     1         1  walk                0
# 1  0.1922  0.2275  0.0549  1.635344e+12     1         1  walk                0
# 2  0.2510  0.6392  0.0980  1.635344e+12     1         1  walk                0
# 3  0.8235  0.0706  0.7686  1.635344e+12     1         1  walk                0
# 4  0.5020  0.5098  0.6784  1.635344e+12     1         1  walk                0

# %%
# 2s sampling --> 20 samples
TIME_PERIODS = 20
STEP_DISTANCE = 10

# %%
def create_segments_and_labels(df, time_steps, step, label_name):

    # x, y, z acceleration as features
    N_FEATURES = 12
    # Number of steps to advance in each iteration (for me, it should always
    # be equal to the time_steps in order to have no overlap between segments)
    # step = time_steps
    segments = []
    labels = []
    series_list = []
    for i in range(0, len(df) - time_steps, step):
        for metric in metrics:
            s = df[metric].values[i: i + time_steps]
            series_list.append(s)
        # Retrieve the most often used label in this segment
        label = stats.mode(df[label_name][i: i + time_steps])[0][0]
        segments.append(series_list)
        series_list = []
        labels.append(label)

    # Bring the segments into a better shape
    reshaped_segments = np.asarray(segments, dtype= np.float32).reshape(-1, time_steps, N_FEATURES)
    labels = np.asarray(labels)

    return reshaped_segments, labels

x_train, y_train = create_segments_and_labels(df_train,
                                              TIME_PERIODS,
                                              STEP_DISTANCE,
                                              LABEL)

# %%
print('x_train shape: ', x_train.shape)
print(x_train.shape[0], 'training samples')
print('y_train shape: ', y_train.shape)
# Out:
# x_train shape:  (280, 20, 12)
# 280 training samples
# y_train shape:  (280,)

# %%
num_time_periods, num_sensors = x_train.shape[1], x_train.shape[2]
num_classes = le.classes_.size
print(list(le.classes_))
# Out:
# [1, 2, 3]

# %%
input_shape = (num_time_periods*num_sensors)
x_train = x_train.reshape(x_train.shape[0], input_shape)
print('x_train shape:', x_train.shape)
print('input_shape:', input_shape)
# Out:
# x_train shape: (280, 240)
# input_shape: 240

# %% [markdown]
# ## Input shape: 20x12 (20 samples/2s and 12 sensor data)

# %%
x_train = x_train.astype('float32')
y_train = y_train.astype('float32')

# %%
y_train_hot = np_utils.to_categorical(y_train, num_classes)
print('New y_train shape: ', y_train_hot.shape)
# Out:
# New y_train shape:  (280, 3)

# %%
model_m = Sequential()
# Remark: since coreml cannot accept vector shapes of complex shape like
# [80,3] this workaround is used in order to reshape the vector internally
# prior feeding it into the network
model_m.add(Reshape((TIME_PERIODS, 12), input_shape=(input_shape,)))
model_m.add(Dense(100, activation='relu'))
model_m.add(Dense(100, activation='relu'))
model_m.add(Dense(100, activation='relu'))
model_m.add(Flatten())
model_m.add(Dense(num_classes, activation='softmax'))
print(model_m.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 20, 12)            0
# _________________________________________________________________
# dense (Dense)                (None, 20, 100)           1300
# _________________________________________________________________
# dense_1 (Dense)              (None, 20, 100)           10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 20, 100)           10100
# _________________________________________________________________
# flatten (Flatten)            (None, 2000)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 6003
# =================================================================
# Total params: 27,503
# Trainable params: 27,503
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
callbacks_list = [
    keras.callbacks.ModelCheckpoint(
        filepath='best_model.{epoch:02d}-{val_loss:.2f}.h5',
        monitor='val_loss', save_best_only=True),
    keras.callbacks.EarlyStopping(monitor='acc', patience=1)
]

model_m.compile(loss='categorical_crossentropy',
                optimizer='adam', metrics=['accuracy'])

# Hyper-parameters
BATCH_SIZE = 400
EPOCHS = 50

# Enable validation to use ModelCheckpoint and EarlyStopping callbacks.
history = model_m.fit(x_train,
                      y_train_hot,
                      batch_size=BATCH_SIZE,
                      epochs=EPOCHS,
                      callbacks=callbacks_list,
                      validation_split=0.2,
                      verbose=1)
# Out:
# Epoch 1/50
# 1/1 [==============================] - 1s 1s/step - loss: 1.0652 - accuracy: 0.3482 - val_loss: 1.6545 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0284 - accuracy: 0.4330 - val_loss: 1.9040 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 1/1 [==============================] - 0s 118ms/step - loss: 1.0108 - accuracy: 0.4955 - val_loss: 2.0367 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 1/1 [==============================] - 0s 44ms/step - loss: 0.9971 - accuracy: 0.5580 - val_loss: 2.0550 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 1/1 [==============================] - 0s 82ms/step - loss: 0.9808 - accuracy: 0.6652 - val_loss: 1.9990 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 1/1 [==============================] - 0s 69ms/step - loss: 0.9624 - accuracy: 0.7054 - val_loss: 1.9090 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 1/1 [==============================] - 0s 37ms/step - loss: 0.9436 - accuracy: 0.7366 - val_loss: 1.8136 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 1/1 [==============================] - 0s 42ms/step - loss: 0.9252 - accuracy: 0.7545 - val_loss: 1.7301 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 1/1 [==============================] - 0s 33ms/step - loss: 0.9068 - accuracy: 0.7723 - val_loss: 1.6677 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 1/1 [==============================] - 0s 41ms/step - loss: 0.8877 - accuracy: 0.7768 - val_loss: 1.6308 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 1/1 [==============================] - 0s 52ms/step - loss: 0.8668 - accuracy: 0.7812 - val_loss: 1.6201 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 1/1 [==============================] - 0s 44ms/step - loss: 0.8435 - accuracy: 0.7902 - val_loss: 1.6314 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 1/1 [==============================] - 0s 73ms/step - loss: 0.8181 - accuracy: 0.7946 - val_loss: 1.6562 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 1/1 [==============================] - 0s 92ms/step - loss: 0.7914 - accuracy: 0.7991 - val_loss: 1.6803 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 1/1 [==============================] - 0s 60ms/step - loss: 0.7637 - accuracy: 0.8036 - val_loss: 1.6852 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 1/1 [==============================] - 0s 64ms/step - loss: 0.7345 - accuracy: 0.8036 - val_loss: 1.6569 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 1/1 [==============================] - 0s 57ms/step - loss: 0.7034 - accuracy: 0.8125 - val_loss: 1.5913 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 1/1 [==============================] - 0s 63ms/step - loss: 0.6703 - accuracy: 0.8214 - val_loss: 1.4980 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 1/1 [==============================] - 0s 42ms/step - loss: 0.6362 - accuracy: 0.8438 - val_loss: 1.4042 - val_accuracy: 0.0179
# Epoch 20/50
# 1/1 [==============================] - 0s 53ms/step - loss: 0.6018 - accuracy: 0.8616 - val_loss: 1.3411 - val_accuracy: 0.0357
# Epoch 21/50
# 1/1 [==============================] - 0s 46ms/step - loss: 0.5667 - accuracy: 0.8705 - val_loss: 1.3270 - val_accuracy: 0.0536
# Epoch 22/50
# 1/1 [==============================] - 0s 50ms/step - loss: 0.5306 - accuracy: 0.8839 - val_loss: 1.3457 - val_accuracy: 0.0536
# Epoch 23/50
# 1/1 [==============================] - 0s 78ms/step - loss: 0.4949 - accuracy: 0.8839 - val_loss: 1.3464 - val_accuracy: 0.0536
# Epoch 24/50
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4603 - accuracy: 0.8929 - val_loss: 1.2832 - val_accuracy: 0.1071
# Epoch 25/50
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4261 - accuracy: 0.9062 - val_loss: 1.1751 - val_accuracy: 0.2321
# Epoch 26/50
# 1/1 [==============================] - 0s 86ms/step - loss: 0.3933 - accuracy: 0.9241 - val_loss: 1.0976 - val_accuracy: 0.3571
# Epoch 27/50
# 1/1 [==============================] - 0s 83ms/step - loss: 0.3625 - accuracy: 0.9375 - val_loss: 1.0975 - val_accuracy: 0.3750
# Epoch 28/50
# 1/1 [==============================] - 0s 73ms/step - loss: 0.3327 - accuracy: 0.9420 - val_loss: 1.1216 - val_accuracy: 0.3571
# Epoch 29/50
# 1/1 [==============================] - 0s 69ms/step - loss: 0.3052 - accuracy: 0.9375 - val_loss: 1.0810 - val_accuracy: 0.4286
# Epoch 30/50
# 1/1 [==============================] - 0s 169ms/step - loss: 0.2794 - accuracy: 0.9375 - val_loss: 0.9898 - val_accuracy: 0.4643
# Epoch 31/50
# 1/1 [==============================] - 0s 73ms/step - loss: 0.2553 - accuracy: 0.9509 - val_loss: 0.9488 - val_accuracy: 0.4643
# Epoch 32/50
# 1/1 [==============================] - 0s 65ms/step - loss: 0.2334 - accuracy: 0.9509 - val_loss: 0.9792 - val_accuracy: 0.4643
# Epoch 33/50
# 1/1 [==============================] - 0s 182ms/step - loss: 0.2128 - accuracy: 0.9509 - val_loss: 0.9754 - val_accuracy: 0.4643
# Epoch 34/50
# 1/1 [==============================] - 0s 53ms/step - loss: 0.1942 - accuracy: 0.9509 - val_loss: 0.9080 - val_accuracy: 0.4643
# Epoch 35/50
# 1/1 [==============================] - 0s 111ms/step - loss: 0.1767 - accuracy: 0.9598 - val_loss: 0.8766 - val_accuracy: 0.5357
# Epoch 36/50
# 1/1 [==============================] - 0s 154ms/step - loss: 0.1608 - accuracy: 0.9688 - val_loss: 0.9017 - val_accuracy: 0.5000
# Epoch 37/50
# 1/1 [==============================] - 0s 104ms/step - loss: 0.1457 - accuracy: 0.9777 - val_loss: 0.8951 - val_accuracy: 0.5357
# Epoch 38/50
# 1/1 [==============================] - 0s 49ms/step - loss: 0.1320 - accuracy: 0.9821 - val_loss: 0.8570 - val_accuracy: 0.5536
# Epoch 39/50
# 1/1 [==============================] - 0s 69ms/step - loss: 0.1192 - accuracy: 0.9866 - val_loss: 0.8322 - val_accuracy: 0.5714
# Epoch 40/50
# 1/1 [==============================] - 0s 90ms/step - loss: 0.1075 - accuracy: 0.9866 - val_loss: 0.8571 - val_accuracy: 0.5536
# Epoch 41/50
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0967 - accuracy: 0.9866 - val_loss: 0.8677 - val_accuracy: 0.5536
# Epoch 42/50
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0868 - accuracy: 0.9866 - val_loss: 0.8381 - val_accuracy: 0.5893
# Epoch 43/50
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0776 - accuracy: 0.9955 - val_loss: 0.8283 - val_accuracy: 0.5893
# Epoch 44/50
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0694 - accuracy: 1.0000 - val_loss: 0.8493 - val_accuracy: 0.5536
# Epoch 45/50
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0617 - accuracy: 1.0000 - val_loss: 0.8699 - val_accuracy: 0.5536
# Epoch 46/50
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0549 - accuracy: 1.0000 - val_loss: 0.8581 - val_accuracy: 0.5714
# Epoch 47/50
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0487 - accuracy: 1.0000 - val_loss: 0.8419 - val_accuracy: 0.6071
# Epoch 48/50
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0432 - accuracy: 1.0000 - val_loss: 0.8601 - val_accuracy: 0.5714
# Epoch 49/50
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0382 - accuracy: 1.0000 - val_loss: 0.8859 - val_accuracy: 0.5714
# Epoch 50/50
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0339 - accuracy: 1.0000 - val_loss: 0.8960 - val_accuracy: 0.5714

# %%
plt.figure(figsize=(6, 4))
plt.plot(history.history['accuracy'], 'r', label='Accuracy of training data')
plt.plot(history.history['val_accuracy'], 'b', label='Accuracy of validation data')
plt.plot(history.history['loss'], 'r--', label='Loss of training data')
plt.plot(history.history['val_loss'], 'b--', label='Loss of validation data')
plt.title('Model Accuracy and Loss')
plt.ylabel('Accuracy and Loss')
plt.xlabel('Training Epoch')
plt.ylim(0)
plt.legend()
plt.show()

# Print confusion matrix for training data
y_pred_train = model_m.predict(x_train)
# Take the class with the highest probability from the train predictions
max_y_pred_train = np.argmax(y_pred_train, axis=1)
print(classification_report(y_train, max_y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99        93
#          1.0       1.00      0.74      0.85        93
#          2.0       0.81      1.00      0.90        94
#
#     accuracy                           0.91       280
#    macro avg       0.93      0.91      0.91       280
# weighted avg       0.93      0.91      0.91       280

# %%
df_test.shape
# Out:
# (1402, 17)

# %%
df_test.head()
# Out:
#           G1X       G1Y       G1Z       A1X       A1Y       A1Z       G2X  \
# 934  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 935  1.548767  0.381470  0.099182  0.058105  0.026123  0.054199  0.000000
# 936  0.915527  1.571655  1.617432  0.059326  0.014160  0.000488  1.533508
# 937  1.472473  1.831055  0.495911  0.061523  0.000488  0.003906  1.335144
# 938  0.846863  1.609802  0.694275  0.061523  0.025635  0.000244  0.190735
#
#           G2Y       G2Z      A2X       A2Y       A2Z     timestamp  User  \
# 934  0.000000  0.000000  0.00000  0.000000  0.000000  1.635345e+12     3
# 935  0.000000  0.000000  0.00000  0.000000  0.000000  1.635345e+12     3
# 936  0.228882  0.000000  0.03125  0.025879  0.051025  1.635345e+12     3
# 937  0.213623  0.000000  0.03125  0.061035  0.039795  1.635345e+12     3
# 938  0.167847  0.915527  0.03540  0.052246  0.043945  1.635345e+12     3
#
#      Activity label  ActivityEncoded
# 934         1  walk                0
# 935         1  walk                0
# 936         1  walk                0
# 937         1  walk                0
# 938         1  walk                0

# %%
test_model_df = df_test[df_test["Activity"] == 1]

# %%
test_model_df.shape
# Out:
# (476, 17)

# %%
metrics = ['G1X', 'G1Y', 'G1Z', 'A1X', 'A1Y', 'A1Z', 'G2X', 'G2Y', 'G2Z', 'A2X', 'A2Y', 'A2Z']

# %%
series_list = []
segments = []
for metric in metrics:
    s = test_model_df[metric].values[1: 1+20]
    series_list.append(s)
segments.append(series_list)

# %%
reshaped_segments = np.asarray(segments, dtype= np.float32).reshape(-1, 20, 12)

# %%
reshaped_segments.shape
# Out:
# (1, 20, 12)

# %%
y_pred_test = model_m.predict(reshaped_segments)

# %%
y_pred_test
# Out:
# array([[1.0000000e+00, 2.8977685e-17, 2.6952313e-18]], dtype=float32)
