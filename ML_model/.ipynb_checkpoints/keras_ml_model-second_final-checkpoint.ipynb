# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

np.random.seed = 100

# %% [markdown]
# ## Load data

# %%
standing_jen = pd.read_csv(r'../datasets/raw_data/standing_jen.csv')
standing_shreya = pd.read_csv(r'../datasets/raw_data/standing_shreya.csv')
standing_sirui = pd.read_csv(r'../datasets/raw_data/standing_sirui.csv')
standing_benita = pd.read_csv(r'../datasets/raw_data/standing_benita.csv')
standing_nguyen = pd.read_csv(r'../datasets/raw_data/standing_nguyen.csv')

standing_jen["User"] = 1
standing_shreya["User"] = 2
standing_sirui["User"] = 3
standing_benita["User"] = 4
standing_nguyen["User"] = 5

standing_all = standing_jen[:100].append(standing_shreya[:100], ignore_index=True).append(standing_benita[:100], ignore_index=True).append(standing_nguyen[:100], ignore_index=True).append(standing_sirui[:100], ignore_index=True)

standing_all.shape

standing_all["Activity"] = 0

# %%
jumping_jen = pd.read_csv(r'../datasets/raw_data/jumping_jen.csv')
jumping_shreya = pd.read_csv(r'../datasets/raw_data/jumping_shreya.csv')
jumping_sirui = pd.read_csv(r'../datasets/raw_data/jumping_sirui.csv')
jumping_benita = pd.read_csv(r'../datasets/raw_data/jumping_benita.csv')
jumping_nguyen = pd.read_csv(r'../datasets/raw_data/jumping_nguyen.csv')

jumping_jen["User"] = 1
jumping_shreya["User"] = 2
jumping_sirui["User"] = 3
jumping_benita["User"] = 4
jumping_nguyen["User"] = 5

jumping_all = jumping_jen.append(jumping_shreya, ignore_index=True).append(jumping_benita, ignore_index=True).append(jumping_nguyen, ignore_index=True).append(jumping_sirui, ignore_index=True)

jumping_all.shape

jumping_all["Activity"] = 2

# %%
running_jen = pd.read_csv(r'../datasets/raw_data/running_jen.csv')
running_shreya = pd.read_csv(r'../datasets/raw_data/running_shreya.csv')
running_sirui = pd.read_csv(r'../datasets/raw_data/running_sirui.csv')
running_benita = pd.read_csv(r'../datasets/raw_data/running_benita.csv')
running_nguyen = pd.read_csv(r'../datasets/raw_data/running_nguyen.csv')

running_jen["User"] = 1
running_shreya["User"] = 2
running_sirui["User"] = 3
running_benita["User"] = 4
running_nguyen["User"] = 5

running_all = running_jen.append(running_shreya, ignore_index=True).append(running_benita, ignore_index=True).append(running_nguyen, ignore_index=True).append(running_sirui, ignore_index=True)

running_all.shape

running_all["Activity"] = 3

# %%
walking_jen = pd.read_csv(r'../datasets/raw_data/walking_jen.csv')
walking_shreya = pd.read_csv(r'../datasets/raw_data/walking_shreya.csv')
walking_sirui = pd.read_csv(r'../datasets/raw_data/walking_sirui.csv')
walking_benita = pd.read_csv(r'../datasets/raw_data/walking_benita.csv')
walking_nguyen = pd.read_csv(r'../datasets/raw_data/walking_nguyen.csv')

walking_jen["User"] = 1
walking_shreya["User"] = 2
walking_sirui["User"] = 3
walking_benita["User"] = 4
walking_nguyen["User"] = 5

walking_all = walking_jen.append(walking_shreya, ignore_index=True).append(walking_benita, ignore_index=True).append(walking_nguyen, ignore_index=True).append(walking_sirui, ignore_index=True)

walking_all.shape

walking_all["Activity"] = 1

# %%
act_dict = {0: 'stand',
            1: 'walk',
            2: 'jump',
            3: 'run'}

# %% [markdown]
# ### Mark actitvities:
# Stand: 0
# Walking: 1
# Jumping: 2
# Running: 3

# %%
data_all = standing_all.append(walking_all,ignore_index=True).append(running_all, ignore_index=True).append(jumping_all, ignore_index=True)
data_all['label'] =  data_all.Activity.apply(lambda Activity: act_dict[Activity])

# %%
data_all['label']
# Out:
# 0       stand
# 1       stand
# 2       stand
# 3       stand
# 4       stand
#         ...
# 7479     jump
# 7480     jump
# 7481     jump
# 7482     jump
# 7483     jump
# Name: label, Length: 7484, dtype: object

# %%
data_all.shape
# Out:
# (7484, 16)

# %% [markdown]
# ## Data Exploratory Analysis

# %%
features = ['G1X', 'G1Y', 'G1Z', 'A1X', 'A1Y', 'A1Z', 'G2X', 'G2Y', 'G2Z', 'A2X', 'A2Y', 'A2Z']
N_FEATURES = 12

# %%
def plot_data(start_position, number_of_frames, metrics=features, fourier=False):
    print(f"Looking at {features} for {number_of_frames} from {start_position}")
   
    i, j = 0, 0
    for label in data_all.label.unique():
        mini_df = data_all[data_all['label']==label].iloc[start_position:start_position+number_of_frames].reset_index()
        for feature in features:
            if feature in ['G2X', 'G2Y', 'G2Z', 'A2X', 'A2Y', 'A2Z']:
                axs[i, 1].plot(mini_df[feature])
            else:
                axs[i, 0].plot(mini_df[feature])
                i = i + 1

# %%
plt.rcParams["figure.figsize"] = (20,7)
jumping_all['A1X'].iloc[800:800+50].plot()
jumping_all['A1Y'].iloc[800:800+50].plot()
jumping_all['A1Z'].iloc[800:800+50].plot()
plt.legend()

# %%
import numpy as np
from scipy.signal import butter, lfilter, freqz
import matplotlib.pyplot as plt

data = data_all['A1X']

def butter_lowpass(cutoff, fs, order=5):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    return b, a

def butter_lowpass_filter(data, cutoff, fs, order=5):
    b, a = butter_lowpass(cutoff, fs, order=order)
    y = lfilter(b, a, data)
    return y


# Filter requirements.
order = 5
fs = 20     # sample rate, Hz
cutoff = 9  # desired cutoff frequency of the filter, Hz

# Get the filter coefficients so we can check its frequency response.
b, a = butter_lowpass(cutoff, fs, order)

plt.figure(figsize=(20, 10), dpi=80)
# Plot the frequency response.
w, h = freqz(b, a, worN=8000)
plt.subplot(2, 1, 1)
plt.plot(0.5*fs*w/np.pi, np.abs(h), 'b')
plt.plot(cutoff, 0.5*np.sqrt(2), 'ko')
plt.axvline(cutoff, color='k')
plt.xlim(0, 0.5*fs)
plt.title("Lowpass Filter Frequency Response")
plt.xlabel('Frequency [Hz]')
plt.grid()


# Demonstrate the use of the filter.
# First make some data to be filtered.
T = 690         # seconds
n = 6984 # total number of samples
t = np.linspace(0, 6, 60, endpoint=False)
print(len(t))

# "Noisy" data.  We want to recover the 1.2 Hz signal from this.
# data = np.sin(1.2*2*np.pi*t) + 1.5*np.cos(9*2*np.pi*t) + 0.5*np.sin(12.0*2*np.pi*t)

# Filter the data, and plot both the original and filtered signals.
y = butter_lowpass_filter(data, cutoff, fs, order)


for feature in features:
    if feature in ['A1X', 'A1Y', 'A1Z', 'A2X', 'A2Y', 'A2Z']:
        data_all[feature] = butter_lowpass_filter(data_all[feature], cutoff, fs, order)


plt.figure(figsize=(20, 10), dpi=80)
plt.subplot(2, 1, 2)
data = data
plt.plot(t, data[:60], 'b-', label='data')
plt.plot(t, y[:60], 'g-', linewidth=2, label='filtered data')
plt.xlabel('Time [sec]')
plt.grid()
plt.legend()

plt.subplots_adjust(hspace=1)
plt.show()
# Out:
# 60

# %%
labels = data_all['label']

def plot_activity(activity, data):

    fig, (ax0, ax1, ax2) = plt.subplots(nrows=3,
         figsize=(15, 10),
         sharex=True)
    plot_axis(ax0, range(len(data['timestamp'])), data['A1X'], 'A1X-Axis')
    plot_axis(ax1, range(len(data['timestamp'])), data['A1Y'], 'A1Y-Axis')
    plot_axis(ax2, range(len(data['timestamp'])), data['A1Z'], 'A1Z-Axis')
    plt.subplots_adjust(hspace=0.2)
    fig.suptitle(activity)
    plt.subplots_adjust(top=0.90)
    plt.show()

def plot_axis(ax, x, y, title):

    ax.plot(x, y, 'r')
    ax.set_title(title)
    ax.xaxis.set_visible(False)
    ax.set_ylim([min(y) - np.std(y), max(y) + np.std(y)])
    ax.set_xlim([min(x), max(x)])
    ax.grid(True)

for label in np.unique(labels):
    subset = data_all[data_all['label'] == label][:40]
    plot_activity(label, subset)

# %% [markdown]
# # Lowpass Filter

# %% [markdown]
# # Kalman filter

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
from IPython.display import display, HTML

from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn import preprocessing

import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Reshape
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import np_utils

# %%
# Define column name of the label vector
LABEL = 'ActivityEncoded'
# Transform the labels from String to Integer via LabelEncoder
le = preprocessing.LabelEncoder()
# Add a new column to the existing DataFrame with the encoded values
# data_for_testing[LABEL] = le.fit_transform(data_for_testing['Activity'].values.ravel())
data_all[LABEL] = le.fit_transform(data_all['Activity'].values.ravel())

# %%
data_all[LABEL].min()
# Out:
# 0

# %%
data_all['G1X'].max()
# Out:
# 255.0

# %%
df_test = data_all[data_all['User'] == 5]
df_train = data_all[data_all['User'] != 5]

scales = ['G1X', 'G1Y', 'G1Z', 'G2X', 'G2Y', 'G2Z']

for feature in features:
    df_train.loc[:, feature] = df_train[feature] / 255
    df_test.loc[:, feature] = df_test[feature] / 255
            
# Round numbers
round_dict = {feature: 4 for feature in features}
df_train = df_train.round(round_dict)
df_test = df_test.round(round_dict)
# Out:
# /usr/local/lib/python3.9/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
df_train.head()
# Out:
#       G1X     G1Y     G1Z     A1X     A1Y     A1Z     G2X  G2Y     G2Z  A2X  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0  0.0000  0.0
# 1  0.1961  0.0431  0.6784  0.0024  0.0918  0.0071  0.0000  0.0  0.0000  0.0
# 2  0.1843  0.0235  0.8039  0.0047  0.6437  0.0142  0.0000  0.0  0.0000  0.0
# 3  0.9569  0.0157  0.7529  0.0013  0.8278  0.0108  0.0000  0.0  0.0000  0.0
# 4  0.4157  1.0000  0.3804  0.0015  0.1965  0.0070  0.8157  1.0  0.5804  0.0
#
#       A2Y  A2Z     timestamp  User  Activity  label  ActivityEncoded
# 0  0.0000  0.0  1.637247e+12     1         0  stand                0
# 1  0.0000  0.0  1.637247e+12     1         0  stand                0
# 2  0.0000  0.0  1.637247e+12     1         0  stand                0
# 3  0.0000  0.0  1.637247e+12     1         0  stand                0
# 4  0.4682  0.0  1.637247e+12     1         0  stand                0

# %%
# 2s --> 20 samples
TIME_PERIODS = 20
STEP_DISTANCE = 10

# %%
# ORIGINALLLL
def create_segments_and_labels(df, time_steps, step, label_name):

    # x, y, z acceleration as features
    N_FEATURES = len(features)
    # Number of steps to advance in each iteration (for me, it should always
    # be equal to the time_steps in order to have no overlap between segments)
    # step = time_steps
    segments = []
    labels = []
    series_list = []
    for i in range(0, len(df) - time_steps, step):
        for feature in features:
            s = df[feature].values[i: i + time_steps]
            series_list.append(s)
        # Retrieve the most often used label in this segment
        label = stats.mode(df[label_name][i: i + time_steps])[0][0]
        segments.append(series_list)
        series_list = []
        labels.append(label)

    # Bring the segments into a better shape
    reshaped_segments = np.asarray(segments, dtype= np.float32).reshape(-1, time_steps, N_FEATURES)
    labels = np.asarray(labels)

    return reshaped_segments, labels

x_train, y_train = create_segments_and_labels(df_train, TIME_PERIODS,
                                              STEP_DISTANCE,
                                              LABEL)

x_test, y_test = create_segments_and_labels(df_test, TIME_PERIODS, STEP_DISTANCE, LABEL)

# %%
print('x_train shape: ', x_train.shape)
print(x_train.shape[0], 'training samples')
print('y_train shape: ', y_train.shape)
# Out:
# x_train shape:  (598, 20, 12)
# 598 training samples
# y_train shape:  (598,)

# %%
num_time_periods, num_sensors = x_train.shape[1], x_train.shape[2]
num_classes = le.classes_.size
print(list(le.classes_))
# Out:
# [0, 1, 2, 3]

# %%
input_shape = (num_time_periods*num_sensors)
x_train = x_train.reshape(x_train.shape[0], input_shape)
print('x_train shape:', x_train.shape)
print('input_shape:', input_shape)
# Out:
# x_train shape: (598, 240)
# input_shape: 240

# %% [markdown]
# ## Input shape: 20x12 (20 samples/2s and 12 sensor data)

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
y_train = y_train.astype('float32')

# %%
y_train_hot = np_utils.to_categorical(y_train, num_classes)
print('New y_train shape: ', y_train_hot.shape)
# Out:
# New y_train shape:  (598, 4)

# %%
N_FEATURES = len(features)

model_m = Sequential()
# Remark: since coreml cannot accept vector shapes of complex shape like
# [80,3] this workaround is used in order to reshape the vector internally
# prior feeding it into the network
model_m.add(Reshape((TIME_PERIODS, N_FEATURES), input_shape=(input_shape,)))
model_m.add(Dense(200, activation='relu'))
model_m.add(Dropout(0.2))
model_m.add(Dense(170, activation='relu'))
model_m.add(Dropout(0.3))
model_m.add(Dense(150, activation='relu'))
model_m.add(Dropout(0.3))
model_m.add(Dense(150, activation='relu'))
model_m.add(Dropout(0.4))
model_m.add(Dense(100, activation='relu'))
model_m.add(Flatten())
model_m.add(Dense(num_classes, activation='softmax'))
print(model_m.summary())
# Out:
# Model: "sequential_29"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_29 (Reshape)         (None, 20, 12)            0
# _________________________________________________________________
# dense_151 (Dense)            (None, 20, 200)           2600
# _________________________________________________________________
# dropout_93 (Dropout)         (None, 20, 200)           0
# _________________________________________________________________
# dense_152 (Dense)            (None, 20, 170)           34170
# _________________________________________________________________
# dropout_94 (Dropout)         (None, 20, 170)           0
# _________________________________________________________________
# dense_153 (Dense)            (None, 20, 150)           25650
# _________________________________________________________________
# dropout_95 (Dropout)         (None, 20, 150)           0
# _________________________________________________________________
# dense_154 (Dense)            (None, 20, 150)           22650
# _________________________________________________________________
# dropout_96 (Dropout)         (None, 20, 150)           0
# _________________________________________________________________
# dense_155 (Dense)            (None, 20, 100)           15100
# _________________________________________________________________
# flatten_29 (Flatten)         (None, 2000)              0
# _________________________________________________________________
# dense_156 (Dense)            (None, 4)                 8004
# =================================================================
# Total params: 108,174
# Trainable params: 108,174
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
N_FEATURES = len(features)

model_m = Sequential()
# Remark: since coreml cannot accept vector shapes of complex shape like
# [80,3] this workaround is used in order to reshape the vector internally
# prior feeding it into the network
model_m.add(Reshape((TIME_PERIODS, N_FEATURES), input_shape=(input_shape,)))
model_m.add(Dense(200, activation='relu'))
model_m.add(Dropout(0.2))
model_m.add(Dense(170, activation='relu'))
model_m.add(Dropout(0.4))
model_m.add(Dense(150, activation='relu'))
model_m.add(Dropout(0.5))
model_m.add(Dense(100, activation='relu'))
model_m.add(Flatten())
model_m.add(Dense(num_classes, activation='softmax'))
print(model_m.summary())
# Out:
# Model: "sequential_30"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_30 (Reshape)         (None, 20, 12)            0
# _________________________________________________________________
# dense_157 (Dense)            (None, 20, 200)           2600
# _________________________________________________________________
# dropout_97 (Dropout)         (None, 20, 200)           0
# _________________________________________________________________
# dense_158 (Dense)            (None, 20, 170)           34170
# _________________________________________________________________
# dropout_98 (Dropout)         (None, 20, 170)           0
# _________________________________________________________________
# dense_159 (Dense)            (None, 20, 150)           25650
# _________________________________________________________________
# dropout_99 (Dropout)         (None, 20, 150)           0
# _________________________________________________________________
# dense_160 (Dense)            (None, 20, 100)           15100
# _________________________________________________________________
# flatten_30 (Flatten)         (None, 2000)              0
# _________________________________________________________________
# dense_161 (Dense)            (None, 4)                 8004
# =================================================================
# Total params: 85,524
# Trainable params: 85,524
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
callbacks_list = [
    keras.callbacks.ModelCheckpoint(
        filepath='best_model.{epoch:02d}-{val_loss:.2f}.h5',
        monitor='val_loss', save_best_only=True),
    keras.callbacks.EarlyStopping(monitor='acc', patience=3)
]

model_m.compile(loss='categorical_crossentropy',
                optimizer='adam', metrics=['accuracy'])

# Hyper-parameters
BATCH_SIZE = 1024
EPOCHS = 200

# Enable validation to use ModelCheckpoint and EarlyStopping callbacks.
history = model_m.fit(x_train,
                      y_train_hot,
                      batch_size=BATCH_SIZE,
                      epochs=EPOCHS,
                      callbacks=callbacks_list,
                      validation_split=0.2,
                      verbose=1)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 3s 3s/step - loss: 1.4179 - accuracy: 0.1736 - val_loss: 1.5434 - val_accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 2/200
# 1/1 [==============================] - 0s 409ms/step - loss: 1.3268 - accuracy: 0.3577 - val_loss: 1.6614 - val_accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 3/200
# 1/1 [==============================] - 0s 168ms/step - loss: 1.2475 - accuracy: 0.4247 - val_loss: 1.8173 - val_accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 4/200
# 1/1 [==============================] - 0s 163ms/step - loss: 1.2304 - accuracy: 0.3975 - val_loss: 1.9752 - val_accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 5/200
# 1/1 [==============================] - 0s 307ms/step - loss: 1.2239 - accuracy: 0.3536 - val_loss: 2.0521 - val_accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 6/200
# 1/1 [==============================] - 0s 282ms/step - loss: 1.2289 - accuracy: 0.3619 - val_loss: 2.0168 - val_accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 7/200
# 1/1 [==============================] - 0s 260ms/step - loss: 1.2026 - accuracy: 0.3954 - val_loss: 1.9179 - val_accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 8/200
# 1/1 [==============================] - 0s 219ms/step - loss: 1.1947 - accuracy: 0.4331 - val_loss: 1.7986 - val_accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 9/200
# 1/1 [==============================] - 0s 268ms/step - loss: 1.1840 - accuracy: 0.4686 - val_loss: 1.6871 - val_accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 10/200
# 1/1 [==============================] - 0s 220ms/step - loss: 1.1798 - accuracy: 0.4331 - val_loss: 1.5991 - val_accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 11/200
# 1/1 [==============================] - 0s 158ms/step - loss: 1.1750 - accuracy: 0.4561 - val_loss: 1.5363 - val_accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 12/200
# 1/1 [==============================] - 0s 261ms/step - loss: 1.1669 - accuracy: 0.4791 - val_loss: 1.4969 - val_accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 13/200
# 1/1 [==============================] - 0s 245ms/step - loss: 1.1693 - accuracy: 0.4372 - val_loss: 1.4786 - val_accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 14/200
# 1/1 [==============================] - 0s 213ms/step - loss: 1.1698 - accuracy: 0.4791 - val_loss: 1.4776 - val_accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 15/200
# 1/1 [==============================] - 0s 208ms/step - loss: 1.1617 - accuracy: 0.4958 - val_loss: 1.4926 - val_accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 16/200
# 1/1 [==============================] - 0s 246ms/step - loss: 1.1457 - accuracy: 0.5314 - val_loss: 1.5227 - val_accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 17/200
# 1/1 [==============================] - 0s 247ms/step - loss: 1.1397 - accuracy: 0.4958 - val_loss: 1.5660 - val_accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 18/200
# 1/1 [==============================] - 0s 162ms/step - loss: 1.1159 - accuracy: 0.5460 - val_loss: 1.6227 - val_accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 19/200
# 1/1 [==============================] - 0s 288ms/step - loss: 1.1215 - accuracy: 0.4979 - val_loss: 1.6844 - val_accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 20/200
# 1/1 [==============================] - 0s 200ms/step - loss: 1.1070 - accuracy: 0.5209 - val_loss: 1.7410 - val_accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 21/200
# 1/1 [==============================] - 0s 161ms/step - loss: 1.0984 - accuracy: 0.5607 - val_loss: 1.7806 - val_accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 22/200
# 1/1 [==============================] - 0s 329ms/step - loss: 1.0776 - accuracy: 0.5711 - val_loss: 1.7929 - val_accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 23/200
# 1/1 [==============================] - 0s 207ms/step - loss: 1.0829 - accuracy: 0.5607 - val_loss: 1.7731 - val_accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 24/200
# 1/1 [==============================] - 0s 217ms/step - loss: 1.0502 - accuracy: 0.5628 - val_loss: 1.7279 - val_accuracy: 0.0000e+00
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch
- val_accuracy: 0.9000
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 148/200
# 1/1 [==============================] - 0s 247ms/step - loss: 0.0368 - accuracy: 0.9895 - val_loss: 0.2669 - val_accuracy: 0.9083
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 149/200
# 1/1 [==============================] - 0s 146ms/step - loss: 0.0290 - accuracy: 0.9916 - val_loss: 0.2615 - val_accuracy: 0.9083
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 150/200
# 1/1 [==============================] - 0s 195ms/step - loss: 0.0293 - accuracy: 0.9874 - val_loss: 0.2676 - val_accuracy: 0.9083
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 151/200
# 1/1 [==============================] - 0s 270ms/step - loss: 0.0333 - accuracy: 0.9874 - val_loss: 0.2878 - val_accuracy: 0.9083
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 152/200
# 1/1 [==============================] - 0s 151ms/step - loss: 0.0364 - accuracy: 0.9874 - val_loss: 0.3204 - val_accuracy: 0.9083
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 153/200
# 1/1 [==============================] - 0s 148ms/step - loss: 0.0270 - accuracy: 0.9916 - val_loss: 0.3283 - val_accuracy: 0.9083
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 154/200
# 1/1 [==============================] - 0s 169ms/step - loss: 0.0432 - accuracy: 0.9812 - val_loss: 0.3296 - val_accuracy: 0.9083
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 155/200
# 1/1 [==============================] - 0s 203ms/step - loss: 0.0330 - accuracy: 0.9937 - val_loss: 0.2897 - val_accuracy: 0.9083
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 156/200
# 1/1 [==============================] - 0s 266ms/step - loss: 0.0277 - accuracy: 0.9916 - val_loss: 0.2687 - val_accuracy: 0.9083
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 157/200
# 1/1 [==============================] - 0s 201ms/step - loss: 0.0317 - accuracy: 0.9916 - val_loss: 0.2906 - val_accuracy: 0.9083
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 158/200
# 1/1 [==============================] - 0s 265ms/step - loss: 0.0227 - accuracy: 0.9958 - val_loss: 0.2991 - val_accuracy: 0.9083
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 159/200
# 1/1 [==============================] - 0s 169ms/step - loss: 0.0253 - accuracy: 0.9937 - val_loss: 0.2922 - val_accuracy: 0.9083
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 160/200
# 1/1 [==============================] - 0s 169ms/step - loss: 0.0432 - accuracy: 0.9854 - val_loss: 0.2844 - val_accuracy: 0.9083
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 161/200
# 1/1 [==============================] - 0s 274ms/step - loss: 0.0173 - accuracy: 0.9937 - val_loss: 0.2719 - val_accuracy: 0.9083
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 162/200
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0230 - accuracy: 0.9958 - val_loss: 0.2899 - val_accuracy: 0.9083
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 163/200
# 1/1 [==============================] - 0s 236ms/step - loss: 0.0246 - accuracy: 0.9916 - val_loss: 0.3146 - val_accuracy: 0.9083
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 164/200
# 1/1 [==============================] - 0s 160ms/step - loss: 0.0239 - accuracy: 0.9895 - val_loss: 0.3253 - val_accuracy: 0.9000
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 165/200
# 1/1 [==============================] - 0s 202ms/step - loss: 0.0327 - accuracy: 0.9874 - val_loss: 0.3211 - val_accuracy: 0.9083
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 166/200
# 1/1 [==============================] - 0s 158ms/step - loss: 0.0152 - accuracy: 0.9958 - val_loss: 0.3015 - val_accuracy: 0.9083
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 167/200
# 1/1 [==============================] - 0s 196ms/step - loss: 0.0185 - accuracy: 0.9937 - val_loss: 0.2922 - val_accuracy: 0.9083
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 168/200
# 1/1 [==============================] - 0s 264ms/step - loss: 0.0299 - accuracy: 0.9874 - val_loss: 0.2943 - val_accuracy: 0.9083
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 169/200
# 1/1 [==============================] - 0s 160ms/step - loss: 0.0278 - accuracy: 0.9833 - val_loss: 0.3059 - val_accuracy: 0.9083
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 170/200
# 1/1 [==============================] - 0s 233ms/step - loss: 0.0184 - accuracy: 0.9958 - val_loss: 0.3095 - val_accuracy: 0.9083
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 171/200
# 1/1 [==============================] - 0s 191ms/step - loss: 0.0217 - accuracy: 0.9916 - val_loss: 0.3131 - val_accuracy: 0.9083
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 172/200
# 1/1 [==============================] - 0s 147ms/step - loss: 0.0154 - accuracy: 0.9979 - val_loss: 0.3080 - val_accuracy: 0.9083
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 173/200
# 1/1 [==============================] - 0s 190ms/step - loss: 0.0123 - accuracy: 0.9958 - val_loss: 0.3012 - val_accuracy: 0.9167
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 174/200
# 1/1 [==============================] - 0s 242ms/step - loss: 0.0206 - accuracy: 0.9958 - val_loss: 0.2828 - val_accuracy: 0.9167
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 175/200
# 1/1 [==============================] - 0s 180ms/step - loss: 0.0108 - accuracy: 0.9979 - val_loss: 0.2720 - val_accuracy: 0.9167
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 176/200
# 1/1 [==============================] - 0s 148ms/step - loss: 0.0219 - accuracy: 0.9958 - val_loss: 0.2839 - val_accuracy: 0.9083
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 177/200
# 1/1 [==============================] - 0s 213ms/step - loss: 0.0148 - accuracy: 0.9958 - val_loss: 0.2935 - val_accuracy: 0.9000
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 178/200
# 1/1 [==============================] - 0s 232ms/step - loss: 0.0310 - accuracy: 0.9916 - val_loss: 0.3119 - val_accuracy: 0.9000
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 179/200
# 1/1 [==============================] - 0s 179ms/step - loss: 0.0230 - accuracy: 0.9895 - val_loss: 0.3190 - val_accuracy: 0.9000
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 180/200
# 1/1 [==============================] - 0s 301ms/step - loss: 0.0215 - accuracy: 0.9916 - val_loss: 0.3240 - val_accuracy: 0.9000
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 181/200
# 1/1 [==============================] - 0s 178ms/step - loss: 0.0150 - accuracy: 0.9958 - val_loss: 0.3230 - val_accuracy: 0.9083
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 182/200
# 1/1 [==============================] - 0s 173ms/step - loss: 0.0147 - accuracy: 0.9958 - val_loss: 0.3217 - val_accuracy: 0.9083
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 183/200
# 1/1 [==============================] - 0s 168ms/step - loss: 0.0145 - accuracy: 0.9979 - val_loss: 0.2964 - val_accuracy: 0.9250
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 184/200
# 1/1 [==============================] - 0s 209ms/step - loss: 0.0189 - accuracy: 0.9916 - val_loss: 0.2790 - val_accuracy: 0.9250
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 185/200
# 1/1 [==============================] - 0s 205ms/step - loss: 0.0195 - accuracy: 0.9979 - val_loss: 0.2718 - val_accuracy: 0.9250
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 186/200
# 1/1 [==============================] - 0s 164ms/step - loss: 0.0123 - accuracy: 0.9937 - val_loss: 0.2640 - val_accuracy: 0.9167
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 187/200
# 1/1 [==============================] - 0s 145ms/step - loss: 0.0162 - accuracy: 0.9958 - val_loss: 0.2718 - val_accuracy: 0.9167
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 188/200
# 1/1 [==============================] - 0s 150ms/step - loss: 0.0168 - accuracy: 0.9958 - val_loss: 0.2928 - val_accuracy: 0.9000
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 189/200
# 1/1 [==============================] - 0s 172ms/step - loss: 0.0235 - accuracy: 0.9916 - val_loss: 0.3286 - val_accuracy: 0.9000
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 190/200
# 1/1 [==============================] - 0s 165ms/step - loss: 0.0210 - accuracy: 0.9916 - val_loss: 0.3435 - val_accuracy: 0.9000
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 191/200
# 1/1 [==============================] - 0s 164ms/step - loss: 0.0307 - accuracy: 0.9895 - val_loss: 0.3380 - val_accuracy: 0.9083
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 192/200
# 1/1 [==============================] - 0s 189ms/step - loss: 0.0152 - accuracy: 0.9958 - val_loss: 0.3196 - val_accuracy: 0.9167
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 193/200
# 1/1 [==============================] - 0s 168ms/step - loss: 0.0246 - accuracy: 0.9895 - val_loss: 0.2849 - val_accuracy: 0.9250
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 194/200
# 1/1 [==============================] - 0s 159ms/step - loss: 0.0230 - accuracy: 0.9916 - val_loss: 0.2702 - val_accuracy: 0.9250
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 195/200
# 1/1 [==============================] - 0s 166ms/step - loss: 0.0141 - accuracy: 0.9958 - val_loss: 0.2718 - val_accuracy: 0.9250
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 196/200
# 1/1 [==============================] - 0s 191ms/step - loss: 0.0207 - accuracy: 0.9916 - val_loss: 0.3069 - val_accuracy: 0.9167
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 197/200
# 1/1 [==============================] - 0s 186ms/step - loss: 0.0135 - accuracy: 0.9979 - val_loss: 0.3645 - val_accuracy: 0.9000
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 198/200
# 1/1 [==============================] - 0s 196ms/step - loss: 0.0159 - accuracy: 0.9958 - val_loss: 0.3826 - val_accuracy: 0.9000
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 199/200
# 1/1 [==============================] - 0s 157ms/step - loss: 0.0239 - accuracy: 0.9916 - val_loss: 0.3563 - val_accuracy: 0.9083
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 200/200
# 1/1 [==============================] - 0s 154ms/step - loss: 0.0136 - accuracy: 0.9979 - val_loss: 0.3062 - val_accuracy: 0.9250
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy

# %%
plt.figure(figsize=(6, 4))
plt.plot(history.history['accuracy'], 'g', label='Training Accuracy')
plt.plot(history.history['val_accuracy'], 'y', label='Validation Accuracy')
plt.plot(history.history['loss'], 'g--', label='Training Loss')
plt.plot(history.history['val_loss'], 'y--', label='Validation Loss')
# plt.title('Model Accuracy and Loss')
plt.ylabel('Accuracy and Loss')
plt.xlabel('Training Epoch')
plt.ylim(0)
plt.legend()
plt.show()

# Print confusion matrix for training data
y_pred_train = model_m.predict(x_train)
# Take the class with the highest probability from the train predictions
max_y_pred_train = np.argmax(y_pred_train, axis=1)
print(classification_report(y_train, max_y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        40
#          1.0       0.98      1.00      0.99       186
#          2.0       1.00      0.95      0.98       185
#          3.0       0.97      1.00      0.98       187
#
#     accuracy                           0.98       598
#    macro avg       0.99      0.99      0.99       598
# weighted avg       0.99      0.98      0.98       598

# %%
model_m.save_weights('example_model_weights.h5')
model_json = model_m.to_json()
with open("example_model.json", "w") as json_file:
    json_file.write(model_json)

# %%
LABELS = ['standing','walk', 'jump', 'run']

def show_confusion_matrix(validations, predictions):

    matrix = metrics.confusion_matrix(validations, predictions)
    plt.figure(figsize=(6, 4))
    sns.heatmap(matrix,
                cmap='coolwarm',
                linecolor='white',
                linewidths=1,
                xticklabels=LABELS,
                yticklabels=LABELS,
                annot=True,
                fmt='d')
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

y_pred_test = model_m.predict(x_test)
# Take the class with the highest probability from the test predictions
max_y_pred_test = np.argmax(y_pred_test, axis=1)
# max_y_test = np.argmax(y_test, axis=1)

show_confusion_matrix(y_test, max_y_pred_test)

# print(classification_report(y_test, max_y_pred_test))
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 240) for input KerasTensor(type_spec=TensorSpec(shape=(None, 240), dtype=tf.float32, name='reshape_30_input'), name='reshape_30_input', description="created by layer 'reshape_30_input'"), but it was called on an input with incompatible shape (None, 20, 12).

# %%
x_test1 = x_for_testing[3, :].reshape((1, 20, 12))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/5k/4brxlpdx2zbfdjhyjrhnbq8w0000gn/T/ipykernel_24990/3004378636.py in <module>
# ----> 1 x_test1 = x_for_testing[3, :].reshape((1, 20, 12))
#
# NameError: name 'x_for_testing' is not defined

# %%
y_pred_test = model_m.predict(np.asarray(x_walk1).reshape((1, 20, 12)))

# %%
df_train.head
# Out:
# <bound method NDFrame.head of          G1X     G1Y     G1Z     A1X     A1Y     A1Z     G2X     G2Y     G2Z  \
# 0     0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# 1     0.1961  0.0431  0.6784  0.0039  0.1529  0.0118  0.0000  0.0000  0.0000
# 2     0.1843  0.0235  0.8039  0.0039  0.9176  0.0118  0.0000  0.0000  0.0000
# 3     0.9569  0.0157  0.7529  0.0000  0.5216  0.0118  0.0000  0.0000  0.0000
# 4     0.4157  1.0000  0.3804  0.0039  0.2196  0.0039  0.8157  1.0000  0.5804
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 7652  0.7843  0.0471  0.6980  0.8588  0.8353  1.0000  0.4549  0.0588  0.3059
# 7653  0.2196  0.0941  1.0000  0.4980  0.1804  0.9882  0.5922  0.9686  0.4902
# 7654  0.0980  0.6588  1.0000  0.4980  0.4314  0.9843  0.6196  0.8275  0.3529
# 7655  0.1373  0.7765  1.0000  0.4980  0.6588  0.0118  0.1843  0.9725  0.1843
# 7656  0.1059  0.7765  0.9333  0.8471  0.5216  0.3490  0.4745  0.7804  0.1216
#
#          A2X     A2Y     A2Z     timestamp  User  Activity  label  \
# 0     0.0000  0.0000  0.0000  1.637247e+12     1         0  stand
# 1     0.0000  0.0000  0.0000  1.637247e+12     1         0  stand
# 2     0.0000  0.0000  0.0000  1.637247e+12     1         0  stand
# 3     0.0000  0.0000  0.0000  1.637247e+12     1         0  stand
# 4     0.0000  0.7804  0.0000  1.637247e+12     1         0  stand
# ...      ...     ...     ...           ...   ...       ...    ...
# 7652  0.1882  0.3216  0.0314  1.635345e+12     3         2   jump
# 7653  0.8471  0.5961  0.0118  1.635345e+12     3         2   jump
# 7654  0.8039  0.0157  0.9294  1.635345e+12     3         2   jump
# 7655  0.0235  0.7647  0.7647  1.635345e+12     3         2   jump
# 7656  0.1373  0.0706  0.0235  1.635345e+12     3         2   jump
#
#       ActivityEncoded
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ...               ...
# 7652                2
# 7653                2
# 7654                2
# 7655                2
# 7656                2
#
# [6225 rows x 17 columns]>
